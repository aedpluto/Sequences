# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# alows data plots to be displayed
# %matplotlib inline

# generate sigmoid data
x = list(np.arange(-10, 10, 0.5))
y = [1/(1+math.exp(-xi)) for xi in x]

# plot graph data
plt.plot(x, y)
